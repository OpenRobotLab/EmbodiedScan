# %%
from explorer import EmbodiedScanExplorer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_722770/2388366988.py in <module>
# ----> 1 from explorer import EmbodiedScanExplorer
#
# /data/EmbodiedScan/release/EmbodiedScan/embodiedscan/explorer.py in <module>
#       2 from typing import List, Union
#       3
# ----> 4 import mmengine
#       5 import numpy as np
#       6 import open3d as o3d
#
# ModuleNotFoundError: No module named 'mmengine'

# %%
a = EmbodiedScanExplorer(
	dataroot=['data/scannet', 'data/3rscan/', 'data/matterport3d/'],
	ann_file=['data/full_10_visible/train.pkl', 'data/full_10_visible/val.pkl'],
	verbose=True
)
# Out:
# Dataset root
# scannet : data/scannet
# 3rscan : data/3rscan/
# matterport3d : data/matterport3d/
# Loading
# Loading complete

# %%
a.render_image('scannet/scene0000_00', '00000')
# Out:
# Loading image data/scannet/posed_images/scene0000_00/00000.jpg
# Loading image Complete

# %%
a.render_scene('3rscan/02b33dfb-be2b-2d54-92d2-cd012b2b3c40', render_box=True)
# Out:
# same color: remote control  sink
# same color: door  bottle
# same color: towel  cup

# %%
a.render_image('3rscan/02b33dfb-be2b-2d54-92d2-cd012b2b3c40', 'frame-000002')
# Out:
# Loading image data/3rscan/02b33dfb-be2b-2d54-92d2-cd012b2b3c40/sequence/frame-000002.color.jpg
# Loading image Complete

# %%
a.render_scene('matterport3d/17DRP5sb8fy/region0', render_box=True)
# Out:
# same color: toilet paper  bed
# same color: tv  blanket

# %%
a.render_occupancy('scannet/scene0000_00')
# Out:
# same color: table  shower
# same color: pillow  scale
# same color: shoe  doorframe
# same color: guitar  toilet
# same color: paper  microwave

# %%
a.render_scene('scannet/scene0000_00', render_box=True)
# Out:
# same color: dish rack  window
# same color: shelf  clock
# same color: tissue box  switch
# same color: counter  bowl
